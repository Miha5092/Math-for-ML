# %% [markdown]
# ## Initial setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import random

import matplotlib.pyplot as plt

from torch import nn
from torch.utils.data import DataLoader, ConcatDataset
from torchvision.transforms import ToTensor
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
seed = 42
feature_size = 15
baseline_accuracy = 0.9

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

random.seed(seed)
torch_seed = random.randint(0, 2 ** 32 - 1)
numpy_seed = random.randint(0, 2 ** 32 - 1)
torch.manual_seed(torch_seed)
torch.cuda.manual_seed(torch_seed)
np.random.seed(numpy_seed)
# Out:
# Using device: cuda

# %% [markdown]
# ## Model

# %% [markdown]
# ## Model

# %%
class SoftMaxNeuralNetwork(nn.Module):
    def __init__(self, input_size: int, layer_size: int = 64):
        super().__init__()

        self.layers = nn.Sequential(
            nn.Linear(input_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, 2),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        return self.layers(x)
    
    def clasiffy(self, x):
        return torch.argmax(self.forward(x), dim=1)
    
class SigmoidNeuralNetwork(nn.Module):
    def __init__(self, input_size: int, layer_size: int = 64):
        super().__init__()

        self.layers = nn.Sequential(
            nn.Linear(input_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, 1),
        )

    def forward(self, x):
        return self.layers(x).view(-1)
    
    def clasiffy(self, x):
        return torch.round(nn.Sigmoid()(self.forward(x))).view(-1)

# %%
class SoftMaxNeuralNetwork(nn.Module):
    def __init__(self, input_size: int, layer_size: int = 64):
        super().__init__()

        self.layers = nn.Sequential(
            nn.Linear(input_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, 2),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        return self.layers(x)
    
    def clasiffy(self, x):
        return torch.argmax(self.forward(x), dim=1)
    
class SigmoidNeuralNetwork(nn.Module):
    def __init__(self, input_size: int, layer_size: int = 64):
        super().__init__()

        self.layers = nn.Sequential(
            nn.Linear(input_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, layer_size),
            nn.ReLU(),
            nn.Linear(layer_size, 1),
        )

    def forward(self, x):
        return self.layers(x).view(-1)
    
    def clasiffy(self, x):
        return torch.round(nn.Sigmoid()(self.forward(x))).view(-1)

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# #### Data processing functions

# %%
def load_data(feature_size: int):
    X = np.load('../Datasets/kryptonite-%s-X.npy'%(feature_size))
    y = np.load('../Datasets/kryptonite-%s-y.npy'%(feature_size))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

    scaler = StandardScaler().fit(X_train)

    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    return X_train, y_train, X_test, y_test


def convert_to_tensor_dataset(X, y):
    return torch.utils.data.TensorDataset(torch.tensor(X, dtype=torch.float32).to(device), torch.tensor(y, dtype=torch.float32).to(device))

# %% [markdown]
# #### Model optimization functions

# %%
def k_fold(train_dataset, num_folds, num_epochs, learning_rate, batch_size, weight_decay, model_type, layer_size, verbose=False):
    assert model_type == 'softmax' or model_type == 'sigmoid'

    kfold = KFold(n_splits=num_folds, shuffle=True)

    if verbose:
        print('Starting k-fold cross validation')
        print('---------------------------------------')

    fold_no = 0
    fold_losses = []
    fold_accuracies = []

    for train_index, validation_index in kfold.split(train_dataset):
        
        fold_no += 1

        if verbose:
            print('Training on fold:', fold_no)

        if model_type == 'softmax':
            net = SoftMaxNeuralNetwork(feature_size, layer_size).to(device)
            loss_fn = nn.CrossEntropyLoss()
        else:
            net = SigmoidNeuralNetwork(feature_size, layer_size).to(device)
            loss_fn = nn.BCEWithLogitsLoss()
            
        optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate, weight_decay=weight_decay)

        train_subsampler = torch.utils.data.SubsetRandomSampler(train_index)
        validation_subsampler = torch.utils.data.SubsetRandomSampler(validation_index)

        trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_subsampler)
        validationloader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size, sampler=validation_subsampler)

        epoch_losses = []
        epoch_accuracies = []
        for epoch in range(num_epochs):
            batch_losses = []

            for inputs, labels in trainloader:
                net.zero_grad()
                outputs = net(inputs)
                if model_type == 'softmax':
                    labels = labels.long()
                loss = loss_fn(outputs, labels)

                batch_losses.append(loss.item())

                loss.backward()
                optimizer.step()

            epoch_loss = np.mean(batch_losses)
            epoch_losses.append(epoch_loss)

            with torch.no_grad():
                batch_accuracies = []
                for inputs, labels in validationloader:
                    outputs = net.clasiffy(inputs)
                    batch_accuracy = np.mean(outputs.cpu().numpy() == labels.cpu().numpy())
                    batch_accuracies.append(batch_accuracy.item())

            epoch_accuracy = np.mean(batch_accuracies)
            epoch_accuracies.append(epoch_accuracy)

            if epoch % 10 == 0 and verbose:
                print('Epoch:', epoch + 1, 'Loss:', epoch_losses[-1], 'Accuracy:', epoch_accuracies[-1])

        fold_losses.append(epoch_losses)
        fold_accuracies.append(epoch_accuracies)

    fold_accuracies = np.array(fold_accuracies)
    fold_losses = np.array(fold_losses)

    if verbose:
        print('---------------FINISHED----------------')
        print('Accuracies:', fold_accuracies[:, -1])
        print('Average accuracy:', np.mean(fold_accuracies, axis=0)[-1])

    return np.mean(fold_losses, axis=0), np.mean(fold_accuracies, axis=0)

# %%
def grid_search(train_dataset, num_folds, num_epochs, lrs: list, batch_sizes: list, regs: list, model_types: list, layer_sizes: list, verbose=False):
    result_map = dict()
    
    training_accuracies = []
    names = []

    for lr in lrs:
        for batch_size in batch_sizes:
            for reg in regs:
                for model_type in model_types:
                    for layer_size in layer_sizes:
                        train_losses, accuracies = k_fold(train_dataset, num_folds, num_epochs, lr, batch_size, reg, model_type, layer_size, verbose)
                        model_name = f"{model_type} model, {layer_size} neurons, Learning Rate {lr}, Batch Size {batch_size}, Regularization {reg}"
                        result_map[model_name] = accuracies[-1]

                        training_accuracies.append(accuracies)
                        names.append(model_name)

    if verbose:
        for i, name in enumerate(names):
            plt.plot(training_accuracies[i], label=name)

        plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=1)
        plt.yticks(np.arange(0.4, 1.0, 0.05))
        plt.axhline(y=baseline_accuracy, color='r', linestyle='--')
        
        plt.show()
    
    sorted_models = [key for key, value in sorted(filter(lambda item: item[1] > baseline_accuracy, result_map.items()), key=lambda item: item[1], reverse=True)]
    
    print('Models which passed the baseline:', sorted_models)

    return result_map

# %% [markdown]
# ## Model Training and Tunning

# %%
X_train, y_train, X_test, y_test = load_data(feature_size)

# %%
train_dataset = convert_to_tensor_dataset(X_train, y_train)

# %% [markdown]
# #### Hyperparameter Tunning

# %%
results =  grid_search(train_dataset=train_dataset, num_folds=10, num_epochs=50, 
            lrs=                [0.001], 
            batch_sizes=        [2048], 
            regs=               [1e-4, 1e-3], 
            model_types=        ['sigmoid', 'softmax'],
            layer_sizes=        [64, 128],
            verbose=True)
# Out:
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6944599693471735 Accuracy: 0.47347745028409094
# Epoch: 11 Loss: 0.689709251577204 Accuracy: 0.5274103338068181
# Epoch: 21 Loss: 0.6790943741798401 Accuracy: 0.5457874644886364
# Epoch: 31 Loss: 0.6398100527850065 Accuracy: 0.6122381036931819
# Epoch: 41 Loss: 0.5382990674539045 Accuracy: 0.7351518110795454
# Training on fold: 2
# Epoch: 1 Loss: 0.6935723478143866 Accuracy: 0.4843306107954546
# Epoch: 11 Loss: 0.6895986253565008 Accuracy: 0.47889293323863635
# Epoch: 21 Loss: 0.6842760985547846 Accuracy: 0.48987926136363635
# Epoch: 31 Loss: 0.6644581773064353 Accuracy: 0.5538219105113636
# Epoch: 41 Loss: 0.5892972946166992 Accuracy: 0.6561390269886364
# Training on fold: 3
# Epoch: 1 Loss: 0.6937553611668673 Accuracy: 0.48936878551136365
# Epoch: 11 Loss: 0.6889599019830878 Accuracy: 0.5064586292613636
# Epoch: 21 Loss: 0.672447069124742 Accuracy: 0.5762384588068181
# Epoch: 31 Loss: 0.5869663195176558 Accuracy: 0.7243430397727273
# Epoch: 41 Loss: 0.4386766959320415 Accuracy: 0.8355823863636364
# Training on fold: 4
# Epoch: 1 Loss: 0.6941311630335721 Accuracy: 0.49766956676136365
# Epoch: 11 Loss: 0.688073765147816 Accuracy: 0.5110529119318181
# Epoch: 21 Loss: 0.6571859175508673 Accuracy: 0.6098188920454546
# Epoch: 31 Loss: 0.5230676531791687 Accuracy: 0.7756791548295454
# Epoch: 41 Loss: 0.39888705719601025 Accuracy: 0.8564897017045454
# Training on fold: 5
# Epoch: 1 Loss: 0.6935469724915244 Accuracy: 0.4780717329545454
# Epoch: 11 Loss: 0.6899951858953997 Accuracy: 0.517578125
# Epoch: 21 Loss: 0.6850644566796043 Accuracy: 0.49673739346590906
# Epoch: 31 Loss: 0.6722140312194824 Accuracy: 0.5591708096590908
# Epoch: 41 Loss: 0.6211002631620928 Accuracy: 0.6026500355113636
# Training on fold: 6
# Epoch: 1 Loss: 0.6936282298781655 Accuracy: 0.4858842329545454
# Epoch: 11 Loss: 0.6895985494960438 Accuracy: 0.5227716619318181
# Epoch: 21 Loss: 0.6816620284860785 Accuracy: 0.5265447443181819
# Epoch: 31 Loss: 0.6563378193161704 Accuracy: 0.5822310014204546
# Epoch: 41 Loss: 0.5767663175409491 Accuracy: 0.6868563565340908
# Training on fold: 7
# Epoch: 1 Loss: 0.6940046603029425 Accuracy: 0.4709250710227273
# Epoch: 11 Loss: 0.6895533095706593 Accuracy: 0.48131214488636365
# Epoch: 21 Loss: 0.6845270015976646 Accuracy: 0.5102095170454546
# Epoch: 31 Loss: 0.6703023585406217 Accuracy: 0.5390625
# Epoch: 41 Loss: 0.6098170876502991 Accuracy: 0.6634632457386364
# Training on fold: 8
# Epoch: 1 Loss: 0.6937615058638833 Accuracy: 0.48275479403409094
# Epoch: 11 Loss: 0.6898296583782543 Accuracy: 0.5019753196022727
# Epoch: 21 Loss: 0.6809444644234397 Accuracy: 0.5157803622159092
# Epoch: 31 Loss: 0.6249315576119856 Accuracy: 0.6236239346590908
# Epoch: 41 Loss: 0.4951597777279941 Accuracy: 0.77392578125
# Training on fold: 9
# Epoch: 1 Loss: 0.6938374150883068 Accuracy: 0.4866388494318182
# Epoch: 11 Loss: 0.68954721364108 Accuracy: 0.4763405539772727
# Epoch: 21 Loss: 0.6805267225612294 Accuracy: 0.5083673650568181
# Epoch: 31 Loss: 0.6468293991955844 Accuracy: 0.5879350142045454
# Epoch: 41 Loss: 0.5481394095854326 Accuracy: 0.7080743963068181
# Training on fold: 10
# Epoch: 1 Loss: 0.6942216970703818 Accuracy: 0.49056729403409094
# Epoch: 11 Loss: 0.6905158216303046 Accuracy: 0.4772727272727273
# Epoch: 21 Loss: 0.6853699250654741 Accuracy: 0.5146484375
# Epoch: 31 Loss: 0.6682323759252374 Accuracy: 0.5469859730113636
# Epoch: 41 Loss: 0.5971550345420837 Accuracy: 0.63916015625
# ---------------FINISHED----------------
# Accuracies: [0.80324485 0.77618963 0.87857333 0.87759677 0.69371449 0.75801225
#  0.75676935 0.82417436 0.81134588 0.78420188]
# Average accuracy: 0.7963822798295455
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6941427154974504 Accuracy: 0.49109996448863635
# Epoch: 11 Loss: 0.6863383488221602 Accuracy: 0.520751953125
# Epoch: 21 Loss: 0.6546662883325056 Accuracy: 0.5688920454545454
# Epoch: 31 Loss: 0.5144994204694574 Accuracy: 0.7240101207386364
# Epoch: 41 Loss: 0.3758843378587203 Accuracy: 0.8277033025568181
# Training on fold: 2
# Epoch: 1 Loss: 0.6940403580665588 Accuracy: 0.48692737926136365
# Epoch: 11 Loss: 0.6839937513524835 Accuracy: 0.4819557883522727
# Epoch: 21 Loss: 0.643336458639665 Accuracy: 0.6039817116477273
# Epoch: 31 Loss: 0.4620086198503321 Accuracy: 0.7867320667613636
# Epoch: 41 Loss: 0.32216586849906226 Accuracy: 0.865234375
# Training on fold: 3
# Epoch: 1 Loss: 0.6937439441680908 Accuracy: 0.4958939985795454
# Epoch: 11 Loss: 0.6833450956778093 Accuracy: 0.5167791193181819
# Epoch: 21 Loss: 0.6139620813456449 Accuracy: 0.6611550071022727
# Epoch: 31 Loss: 0.4398899403485385 Accuracy: 0.8150967684659092
# Epoch: 41 Loss: 0.3097865012559024 Accuracy: 0.8938876065340908
# Training on fold: 4
# Epoch: 1 Loss: 0.6938308802517977 Accuracy: 0.4763405539772727
# Epoch: 11 Loss: 0.6805128292603926 Accuracy: 0.5553089488636364
# Epoch: 21 Loss: 0.579349935054779 Accuracy: 0.7144664417613636
# Epoch: 31 Loss: 0.4131444286216389 Accuracy: 0.8459028764204546
# Epoch: 41 Loss: 0.31076954711567273 Accuracy: 0.8881392045454546
# Training on fold: 5
# Epoch: 1 Loss: 0.6936569268053229 Accuracy: 0.4917214133522727
# Epoch: 11 Loss: 0.6860380497845736 Accuracy: 0.5052157315340908
# Epoch: 21 Loss: 0.6701672998341647 Accuracy: 0.5457430752840908
# Epoch: 31 Loss: 0.5968402895060453 Accuracy: 0.6634632457386364
# Epoch: 41 Loss: 0.4610698927532543 Accuracy: 0.7646262428977273
# Training on fold: 6
# Epoch: 1 Loss: 0.6943981430747292 Accuracy: 0.4944513494318182
# Epoch: 11 Loss: 0.6865401701493696 Accuracy: 0.4861061789772727
# Epoch: 21 Loss: 0.6666528582572937 Accuracy: 0.555908203125
# Epoch: 31 Loss: 0.5532007163221185 Accuracy: 0.7460493607954546
# Epoch: 41 Loss: 0.389623839746822 Accuracy: 0.8568670099431819
# Training on fold: 7
# Epoch: 1 Loss: 0.6942496624859896 Accuracy: 0.4936301491477273
# Epoch: 11 Loss: 0.6864726326682351 Accuracy: 0.5107199928977273
# Epoch: 21 Loss: 0.6543745398521423 Accuracy: 0.5696688565340908
# Epoch: 31 Loss: 0.5024883096868341 Accuracy: 0.7476029829545454
# Epoch: 41 Loss: 0.35522352294488385 Accuracy: 0.8619939630681819
# Training on fold: 8
# Epoch: 1 Loss: 0.6942247314886614 Accuracy: 0.48570667613636365
# Epoch: 11 Loss: 0.6860531243410978 Accuracy: 0.4982688210227273
# Epoch: 21 Loss: 0.6332107999108054 Accuracy: 0.6363858309659092
# Epoch: 31 Loss: 0.46420492096380755 Accuracy: 0.7993607954545454
# Epoch: 41 Loss: 0.3472562757405368 Accuracy: 0.8600408380681819
# Training on fold: 9
# Epoch: 1 Loss: 0.694233157417991 Accuracy: 0.5348233309659092
# Epoch: 11 Loss: 0.6864185549996116 Accuracy: 0.4877485795454546
# Epoch: 21 Loss: 0.6393926956436851 Accuracy: 0.6015625
# Epoch: 31 Loss: 0.5009651996872642 Accuracy: 0.7369717684659092
# Epoch: 41 Loss: 0.365627340295098 Accuracy: 0.8570667613636364
# Training on fold: 10
# Epoch: 1 Loss: 0.6936652877114036 Accuracy: 0.49722567471590906
# Epoch: 11 Loss: 0.6855929331345991 Accuracy: 0.5086558948863636
# Epoch: 21 Loss: 0.6706922216848894 Accuracy: 0.5200861150568181
# Epoch: 31 Loss: 0.5494496063752607 Accuracy: 0.7025479403409092
# Epoch: 41 Loss: 0.3949555375359275 Accuracy: 0.8246182528409092
# ---------------FINISHED----------------
# Accuracies: [0.86973988 0.9033647  0.9099565  0.90043501 0.83957741 0.90514027
#  0.87497781 0.902943   0.89588512 0.90602805]
# Average accuracy: 0.8908047762784091
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6946150118654425 Accuracy: 0.5132723721590908
# Epoch: 11 Loss: 0.6906797723336653 Accuracy: 0.5020640980113636
# Epoch: 21 Loss: 0.6866903413425792 Accuracy: 0.4821333451704546
# Epoch: 31 Loss: 0.6792104894464667 Accuracy: 0.5234153053977273
# Epoch: 41 Loss: 0.6599599664861505 Accuracy: 0.5927512428977273
# Training on fold: 2
# Epoch: 1 Loss: 0.6935632499781522 Accuracy: 0.5077903053977273
# Epoch: 11 Loss: 0.6886792291294445 Accuracy: 0.5316938920454546
# Epoch: 21 Loss: 0.6616070649840615 Accuracy: 0.5897327769886364
# Epoch: 31 Loss: 0.5871069756421176 Accuracy: 0.7353293678977273
# Epoch: 41 Loss: 0.5209063670851968 Accuracy: 0.8152521306818181
# Training on fold: 3
# Epoch: 1 Loss: 0.6934793320569125 Accuracy: 0.4814897017045454
# Epoch: 11 Loss: 0.6900274320082231 Accuracy: 0.5122292258522727
# Epoch: 21 Loss: 0.6778928149830211 Accuracy: 0.5446111505681819
# Epoch: 31 Loss: 0.6398956342176958 Accuracy: 0.6318581321022727
# Epoch: 41 Loss: 0.5741222880103372 Accuracy: 0.7516645951704546
# Training on fold: 4
# Epoch: 1 Loss: 0.6933689984408292 Accuracy: 0.4852849786931818
# Epoch: 11 Loss: 0.6894238916310397 Accuracy: 0.4853515625
# Epoch: 21 Loss: 0.6710414778102528 Accuracy: 0.5823641690340908
# Epoch: 31 Loss: 0.6160608259114352 Accuracy: 0.6669921875
# Epoch: 41 Loss: 0.5355654196305708 Accuracy: 0.7785422585227273
# Training on fold: 5
# Epoch: 1 Loss: 0.6934163570404053 Accuracy: 0.5037508877840909
# Epoch: 11 Loss: 0.6901697191325101 Accuracy: 0.49300870028409094
# Epoch: 21 Loss: 0.6791692213578657 Accuracy: 0.5295854048295454
# Epoch: 31 Loss: 0.6407954421910372 Accuracy: 0.6124156605113636
# Epoch: 41 Loss: 0.5799350142478943 Accuracy: 0.7292258522727273
# Training on fold: 6
# Epoch: 1 Loss: 0.6933633956042203 Accuracy: 0.4928977272727273
# Epoch: 11 Loss: 0.690086072141474 Accuracy: 0.5005992542613636
# Epoch: 21 Loss: 0.682059873234142 Accuracy: 0.5086337002840909
# Epoch: 31 Loss: 0.6363461830399253 Accuracy: 0.6243785511363636
# Epoch: 41 Loss: 0.5467097325758501 Accuracy: 0.7685546875
# Training on fold: 7
# Epoch: 1 Loss: 0.693711134520444 Accuracy: 0.50439453125
# Epoch: 11 Loss: 0.6902460997754877 Accuracy: 0.5052601207386364
# Epoch: 21 Loss: 0.6859349391677163 Accuracy: 0.49849076704545453
# Epoch: 31 Loss: 0.6747393770651384 Accuracy: 0.5491166548295454
# Epoch: 41 Loss: 0.6404458501122214 Accuracy: 0.6157670454545454
# Training on fold: 8
# Epoch: 1 Loss: 0.6935189203782515 Accuracy: 0.5005548650568181
# Epoch: 11 Loss: 0.690579045902599 Accuracy: 0.48697176846590906
# Epoch: 21 Loss: 0.6854788877747275 Accuracy: 0.5282981178977273
# Epoch: 31 Loss: 0.6673096689310941 Accuracy: 0.5687588778409092
# Epoch: 41 Loss: 0.61212312633341 Accuracy: 0.6847700639204546
# Training on fold: 9
# Epoch: 1 Loss: 0.6936249299482866 Accuracy: 0.4780717329545454
# Epoch: 11 Loss: 0.6898502707481384 Accuracy: 0.49549449573863635
# Epoch: 21 Loss: 0.6834182956001975 Accuracy: 0.5002885298295454
# Epoch: 31 Loss: 0.6666215549815785 Accuracy: 0.5469859730113636
# Epoch: 41 Loss: 0.6348027261820707 Accuracy: 0.6091530539772727
# Training on fold: 10
# Epoch: 1 Loss: 0.693813145160675 Accuracy: 0.5103204900568181
# Epoch: 11 Loss: 0.689404698935422 Accuracy: 0.5132945667613636
# Epoch: 21 Loss: 0.676580320705067 Accuracy: 0.5498046875
# Epoch: 31 Loss: 0.6336104598912325 Accuracy: 0.6185413707386364
# Epoch: 41 Loss: 0.552369003946131 Accuracy: 0.7860440340909092
# ---------------FINISHED----------------
# Accuracies: [0.69828658 0.85014205 0.79461115 0.83709162 0.77004173 0.83338512
#  0.68976385 0.77734375 0.69196112 0.85134055]
# Average accuracy: 0.7793967507102273
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6939256516369906 Accuracy: 0.5041947798295454
# Epoch: 11 Loss: 0.6874141584743153 Accuracy: 0.5105868252840908
# Epoch: 21 Loss: 0.6706081357869235 Accuracy: 0.5378639914772727
# Epoch: 31 Loss: 0.6115981177850203 Accuracy: 0.6358309659090908
# Epoch: 41 Loss: 0.5269312208349054 Accuracy: 0.7643377130681819
# Training on fold: 2
# Epoch: 1 Loss: 0.6934540921991522 Accuracy: 0.51318359375
# Epoch: 11 Loss: 0.687603159384294 Accuracy: 0.510986328125
# Epoch: 21 Loss: 0.6717950864271685 Accuracy: 0.5402610085227273
# Epoch: 31 Loss: 0.5879522453654896 Accuracy: 0.7089399857954546
# Epoch: 41 Loss: 0.4786191799423911 Accuracy: 0.8482111150568181
# Training on fold: 3
# Epoch: 1 Loss: 0.6942526427182284 Accuracy: 0.5219282670454546
# Epoch: 11 Loss: 0.6877295103940096 Accuracy: 0.516845703125
# Epoch: 21 Loss: 0.6448394060134888 Accuracy: 0.6597789417613636
# Epoch: 31 Loss: 0.4939213042909449 Accuracy: 0.8408203125
# Epoch: 41 Loss: 0.43256834149360657 Accuracy: 0.8831010298295454
# Training on fold: 4
# Epoch: 1 Loss: 0.6940176541155035 Accuracy: 0.5091219815340908
# Epoch: 11 Loss: 0.6876056465235624 Accuracy: 0.5269220525568181
# Epoch: 21 Loss: 0.670239345593886 Accuracy: 0.5420809659090908
# Epoch: 31 Loss: 0.5783153067935597 Accuracy: 0.7401234019886364
# Epoch: 41 Loss: 0.49298132820562884 Accuracy: 0.8306995738636364
# Training on fold: 5
# Epoch: 1 Loss: 0.693536254492673 Accuracy: 0.5064142400568181
# Epoch: 11 Loss: 0.6855509335344488 Accuracy: 0.48837002840909094
# Epoch: 21 Loss: 0.6476421356201172 Accuracy: 0.5813210227272727
# Epoch: 31 Loss: 0.5536914630369707 Accuracy: 0.7432750355113636
# Epoch: 41 Loss: 0.47215517542578955 Accuracy: 0.8602405894886364
# Training on fold: 6
# Epoch: 1 Loss: 0.6933711983940818 Accuracy: 0.49063387784090906
# Epoch: 11 Loss: 0.68697528405623 Accuracy: 0.4829323508522727
# Epoch: 21 Loss: 0.6666304956782948 Accuracy: 0.5335582386363636
# Epoch: 31 Loss: 0.5942944179881703 Accuracy: 0.7192160866477273
# Epoch: 41 Loss: 0.5177543109113519 Accuracy: 0.7895063920454546
# Training on fold: 7
# Epoch: 1 Loss: 0.6939858848398383 Accuracy: 0.485107421875
# Epoch: 11 Loss: 0.6875594312494452 Accuracy: 0.49791370738636365
# Epoch: 21 Loss: 0.6436472697691484 Accuracy: 0.63671875
# Epoch: 31 Loss: 0.5483500849116932 Accuracy: 0.7500887784090908
# Epoch: 41 Loss: 0.4725423807447607 Accuracy: 0.8356711647727273
# Training on fold: 8
# Epoch: 1 Loss: 0.6932716423814947 Accuracy: 0.5012872869318181
# Epoch: 11 Loss: 0.6855676119977777 Accuracy: 0.5323597301136364
# Epoch: 21 Loss: 0.6374984546141191 Accuracy: 0.6324573863636364
# Epoch: 31 Loss: 0.5315831899642944 Accuracy: 0.7778542258522727
# Epoch: 41 Loss: 0.4545000141317194 Accuracy: 0.8726917613636364
# Training on fold: 9
# Epoch: 1 Loss: 0.6933823986486956 Accuracy: 0.5131392045454546
# Epoch: 11 Loss: 0.6861540295860984 Accuracy: 0.4950949928977273
# Epoch: 21 Loss: 0.6451628966764971 Accuracy: 0.5904208096590908
# Epoch: 31 Loss: 0.5460550622506575 Accuracy: 0.7603648792613636
# Epoch: 41 Loss: 0.4742754887450825 Accuracy: 0.8519620028409092
# Training on fold: 10
# Epoch: 1 Loss: 0.6936121366240762 Accuracy: 0.4726340553977273
# Epoch: 11 Loss: 0.6876561750065197 Accuracy: 0.4930752840909091
# Epoch: 21 Loss: 0.6470321254296736 Accuracy: 0.6303488991477273
# Epoch: 31 Loss: 0.5153415582396768 Accuracy: 0.8040660511363636
# Epoch: 41 Loss: 0.45215594497593964 Accuracy: 0.8720259232954546
# ---------------FINISHED----------------
# Accuracies: [0.83504972 0.89726119 0.92209695 0.89217862 0.89277788 0.85715554
#  0.89080256 0.9107555  0.89812678 0.90631658]
# Average accuracy: 0.890252130681818
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6937522183765065 Accuracy: 0.5052379261363636
# Epoch: 11 Loss: 0.6913699453527277 Accuracy: 0.49604936079545453
# Epoch: 21 Loss: 0.6884163780645891 Accuracy: 0.4958939985795454
# Epoch: 31 Loss: 0.6557091366161 Accuracy: 0.5690696022727273
# Epoch: 41 Loss: 0.5399368080225858 Accuracy: 0.7143332741477273
# Training on fold: 2
# Epoch: 1 Loss: 0.6940471638332714 Accuracy: 0.5079900568181819
# Epoch: 11 Loss: 0.6915930617939342 Accuracy: 0.48961292613636365
# Epoch: 21 Loss: 0.6891379952430725 Accuracy: 0.48670543323863635
# Epoch: 31 Loss: 0.6516958583484996 Accuracy: 0.5961470170454546
# Epoch: 41 Loss: 0.5093974687836387 Accuracy: 0.7546830610795454
# Training on fold: 3
# Epoch: 1 Loss: 0.6949202039025046 Accuracy: 0.5
# Epoch: 11 Loss: 0.6917139941995795 Accuracy: 0.5347789417613636
# Epoch: 21 Loss: 0.6870186383073981 Accuracy: 0.5615456321022727
# Epoch: 31 Loss: 0.6305557814511386 Accuracy: 0.6584694602272727
# Epoch: 41 Loss: 0.4852130358869379 Accuracy: 0.8045987215909092
# Training on fold: 4
# Epoch: 1 Loss: 0.6936469565738331 Accuracy: 0.4877485795454546
# Epoch: 11 Loss: 0.6911529844457452 Accuracy: 0.5071244673295454
# Epoch: 21 Loss: 0.6854393265464089 Accuracy: 0.5301402698863636
# Epoch: 31 Loss: 0.6302632635289972 Accuracy: 0.6520108309659092
# Epoch: 41 Loss: 0.5019459236751903 Accuracy: 0.761962890625
# Training on fold: 5
# Epoch: 1 Loss: 0.6934939947995272 Accuracy: 0.5122292258522727
# Epoch: 11 Loss: 0.691586044701663 Accuracy: 0.5098544034090908
# Epoch: 21 Loss: 0.6887893676757812 Accuracy: 0.5245250355113636
# Epoch: 31 Loss: 0.6342061920599504 Accuracy: 0.6566051136363636
# Epoch: 41 Loss: 0.4710072062232278 Accuracy: 0.7774991122159092
# Training on fold: 6
# Epoch: 1 Loss: 0.6942625479264692 Accuracy: 0.5053267045454546
# Epoch: 11 Loss: 0.6916756467385725 Accuracy: 0.5253240411931819
# Epoch: 21 Loss: 0.688982979817824 Accuracy: 0.5178888494318181
# Epoch: 31 Loss: 0.6578611460599032 Accuracy: 0.6268421519886364
# Epoch: 41 Loss: 0.4974954697218808 Accuracy: 0.7833584872159092
# Training on fold: 7
# Epoch: 1 Loss: 0.693776851350611 Accuracy: 0.49769176136363635
# Epoch: 11 Loss: 0.6914129636504434 Accuracy: 0.5181995738636364
# Epoch: 21 Loss: 0.6816327463496815 Accuracy: 0.5696688565340908
# Epoch: 31 Loss: 0.5769754702394659 Accuracy: 0.7394797585227273
# Epoch: 41 Loss: 0.44016537070274353 Accuracy: 0.7992054332386364
# Training on fold: 8
# Epoch: 1 Loss: 0.6939848986538973 Accuracy: 0.5027743252840908
# Epoch: 11 Loss: 0.6912190859968012 Accuracy: 0.5005770596590909
# Epoch: 21 Loss: 0.686581015586853 Accuracy: 0.526123046875
# Epoch: 31 Loss: 0.6499024737964977 Accuracy: 0.6204723011363636
# Epoch: 41 Loss: 0.5144164399667219 Accuracy: 0.7600763494318181
# Training on fold: 9
# Epoch: 1 Loss: 0.6934313936667009 Accuracy: 0.49691495028409094
# Epoch: 11 Loss: 0.6908703608946367 Accuracy: 0.5177778764204546
# Epoch: 21 Loss: 0.6721602461554788 Accuracy: 0.5972789417613636
# Epoch: 31 Loss: 0.5513343052430586 Accuracy: 0.727783203125
# Epoch: 41 Loss: 0.410229355096817 Accuracy: 0.8409312855113636
# Training on fold: 10
# Epoch: 1 Loss: 0.6937302676114169 Accuracy: 0.5049050071022727
# Epoch: 11 Loss: 0.6916901306672529 Accuracy: 0.5048828125
# Epoch: 21 Loss: 0.6909357417713512 Accuracy: 0.5103426846590908
# Epoch: 31 Loss: 0.6882739879868247 Accuracy: 0.5386186079545454
# Epoch: 41 Loss: 0.6665282086892561 Accuracy: 0.5857599431818181
# ---------------FINISHED----------------
# Accuracies: [0.79445579 0.8264604  0.85480291 0.82535067 0.85158469 0.85917525
#  0.82641602 0.82816939 0.85715554 0.74112216]
# Average accuracy: 0.8264692826704545
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6936841878024015 Accuracy: 0.48055752840909094
# Epoch: 11 Loss: 0.6902654116803949 Accuracy: 0.4941184303977273
# Epoch: 21 Loss: 0.6865799968892877 Accuracy: 0.5277876420454546
# Epoch: 31 Loss: 0.6202763535759666 Accuracy: 0.6780894886363636
# Epoch: 41 Loss: 0.4079000678929416 Accuracy: 0.861328125
# Training on fold: 2
# Epoch: 1 Loss: 0.6936693950132891 Accuracy: 0.4989568536931818
# Epoch: 11 Loss: 0.6881271438165144 Accuracy: 0.5143821022727273
# Epoch: 21 Loss: 0.6080416332591664 Accuracy: 0.6786665482954546
# Epoch: 31 Loss: 0.4105311063202945 Accuracy: 0.8403986150568181
# Epoch: 41 Loss: 0.30297013304450293 Accuracy: 0.90673828125
# Training on fold: 3
# Epoch: 1 Loss: 0.6941123713146556 Accuracy: 0.4960715553977273
# Epoch: 11 Loss: 0.6901455304839395 Accuracy: 0.5150257457386364
# Epoch: 21 Loss: 0.6762043725360524 Accuracy: 0.558837890625
# Epoch: 31 Loss: 0.49466475031592627 Accuracy: 0.7915261008522727
# Epoch: 41 Loss: 0.3048908927223899 Accuracy: 0.9072265625
# Training on fold: 4
# Epoch: 1 Loss: 0.6936133883216165 Accuracy: 0.5060813210227273
# Epoch: 11 Loss: 0.6897878430106423 Accuracy: 0.5011097301136364
# Epoch: 21 Loss: 0.6754941019144926 Accuracy: 0.5336692116477273
# Epoch: 31 Loss: 0.5013358024033633 Accuracy: 0.7772771661931819
# Epoch: 41 Loss: 0.31837028535929596 Accuracy: 0.8752219460227273
# Training on fold: 5
# Epoch: 1 Loss: 0.6947989463806152 Accuracy: 0.4846635298295454
# Epoch: 11 Loss: 0.6901859099214728 Accuracy: 0.49451793323863635
# Epoch: 21 Loss: 0.6838985193859447 Accuracy: 0.5359996448863636
# Epoch: 31 Loss: 0.5936557000333612 Accuracy: 0.7102494673295454
# Epoch: 41 Loss: 0.3844596174630252 Accuracy: 0.8766202059659092
# Training on fold: 6
# Epoch: 1 Loss: 0.6936893842437051 Accuracy: 0.49254261363636365
# Epoch: 11 Loss: 0.6906154697591608 Accuracy: 0.49842418323863635
# Epoch: 21 Loss: 0.6871670538728888 Accuracy: 0.5374200994318181
# Epoch: 31 Loss: 0.6027354435487227 Accuracy: 0.6640846946022727
# Epoch: 41 Loss: 0.39640218832276086 Accuracy: 0.8692515980113636
# Training on fold: 7
# Epoch: 1 Loss: 0.6940860531546853 Accuracy: 0.48763760653409094
# Epoch: 11 Loss: 0.6898682876066728 Accuracy: 0.5122736150568181
# Epoch: 21 Loss: 0.6614661866968329 Accuracy: 0.6242897727272727
# Epoch: 31 Loss: 0.42957115173339844 Accuracy: 0.8352272727272727
# Epoch: 41 Loss: 0.27425160868601367 Accuracy: 0.9220525568181819
# Training on fold: 8
# Epoch: 1 Loss: 0.6938363801349293 Accuracy: 0.4927201704545454
# Epoch: 11 Loss: 0.6901427453214471 Accuracy: 0.4770951704545454
# Epoch: 21 Loss: 0.6814014694907449 Accuracy: 0.5340021306818181
# Epoch: 31 Loss: 0.5534783439202742 Accuracy: 0.745361328125
# Epoch: 41 Loss: 0.3466730334542014 Accuracy: 0.85986328125
# Training on fold: 9
# Epoch: 1 Loss: 0.6938832781531594 Accuracy: 0.4939408735795454
# Epoch: 11 Loss: 0.6889607581225309 Accuracy: 0.5257457386363636
# Epoch: 21 Loss: 0.6352401267398488 Accuracy: 0.6624866832386364
# Epoch: 31 Loss: 0.4283018139275638 Accuracy: 0.8406649502840908
# Epoch: 41 Loss: 0.28880939158526336 Accuracy: 0.9032759232954546
# Training on fold: 10
# Epoch: 1 Loss: 0.6933794726024974 Accuracy: 0.49862393465909094
# Epoch: 11 Loss: 0.6899566704576666 Accuracy: 0.5030406605113636
# Epoch: 21 Loss: 0.6713692058216442 Accuracy: 0.5942826704545454
# Epoch: 31 Loss: 0.4696823548186909 Accuracy: 0.7997159090909092
# Epoch: 41 Loss: 0.28961142897605896 Accuracy: 0.9085582386363636
# ---------------FINISHED----------------
# Accuracies: [0.91599343 0.9181907  0.93965288 0.92287376 0.91244229 0.88696289
#  0.93574663 0.91113281 0.92498224 0.91865678]
# Average accuracy: 0.9186634410511363
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6934661919420416 Accuracy: 0.5024192116477273
# Epoch: 11 Loss: 0.6923101327636025 Accuracy: 0.4800248579545454
# Epoch: 21 Loss: 0.6913335431705822 Accuracy: 0.49702592329545453
# Epoch: 31 Loss: 0.6649566617879 Accuracy: 0.6182306463068181
# Epoch: 41 Loss: 0.5397313724864613 Accuracy: 0.7858664772727273
# Training on fold: 2
# Epoch: 1 Loss: 0.6935731931166216 Accuracy: 0.49351917613636365
# Epoch: 11 Loss: 0.6923058845780112 Accuracy: 0.5089888139204546
# Epoch: 21 Loss: 0.6917127641764554 Accuracy: 0.5160688920454546
# Epoch: 31 Loss: 0.6811066757548939 Accuracy: 0.5748623934659092
# Epoch: 41 Loss: 0.5977228012951937 Accuracy: 0.7259632457386364
# Training on fold: 3
# Epoch: 1 Loss: 0.6933181177486073 Accuracy: 0.4909002130681818
# Epoch: 11 Loss: 0.6917216831987555 Accuracy: 0.5043279474431819
# Epoch: 21 Loss: 0.6856636296619069 Accuracy: 0.5194646661931819
# Epoch: 31 Loss: 0.6344873146577314 Accuracy: 0.6845259232954546
# Epoch: 41 Loss: 0.5063601082021539 Accuracy: 0.8299227627840908
# Training on fold: 4
# Epoch: 1 Loss: 0.6938204223459418 Accuracy: 0.486328125
# Epoch: 11 Loss: 0.6922837604175914 Accuracy: 0.5122292258522727
# Epoch: 21 Loss: 0.6889147487553683 Accuracy: 0.5708229758522727
# Epoch: 31 Loss: 0.6406504295089028 Accuracy: 0.6817294034090908
# Epoch: 41 Loss: 0.5313481905243613 Accuracy: 0.8229536576704546
# Training on fold: 5
# Epoch: 1 Loss: 0.6942889040166681 Accuracy: 0.4821111505681818
# Epoch: 11 Loss: 0.6921297962015326 Accuracy: 0.494140625
# Epoch: 21 Loss: 0.689838317307559 Accuracy: 0.5236594460227273
# Epoch: 31 Loss: 0.6475671204653654 Accuracy: 0.6763361150568181
# Epoch: 41 Loss: 0.5194729133085771 Accuracy: 0.8482555042613636
# Training on fold: 6
# Epoch: 1 Loss: 0.6941080797802318 Accuracy: 0.5177334872159092
# Epoch: 11 Loss: 0.691672065041282 Accuracy: 0.5025967684659092
# Epoch: 21 Loss: 0.6871814402666959 Accuracy: 0.5130504261363636
# Epoch: 31 Loss: 0.6549700498580933 Accuracy: 0.614501953125
# Epoch: 41 Loss: 0.5461283759637312 Accuracy: 0.806884765625
# Training on fold: 7
# Epoch: 1 Loss: 0.6934573325243863 Accuracy: 0.4955610795454546
# Epoch: 11 Loss: 0.6924700466069308 Accuracy: 0.4853515625
# Epoch: 21 Loss: 0.6876495751467618 Accuracy: 0.5409712357954546
# Epoch: 31 Loss: 0.6259507211771879 Accuracy: 0.710693359375
# Epoch: 41 Loss: 0.5115569721568715 Accuracy: 0.8272150213068181
# Training on fold: 8
# Epoch: 1 Loss: 0.6932859474962408 Accuracy: 0.5059481534090909
# Epoch: 11 Loss: 0.6916258226741444 Accuracy: 0.5177112926136364
# Epoch: 21 Loss: 0.675106021490964 Accuracy: 0.5748401988636364
# Epoch: 31 Loss: 0.5807564529505643 Accuracy: 0.7516645951704546
# Epoch: 41 Loss: 0.4968230561776595 Accuracy: 0.8323419744318181
# Training on fold: 9
# Epoch: 1 Loss: 0.6933849562298168 Accuracy: 0.5016645951704546
# Epoch: 11 Loss: 0.6920569105581804 Accuracy: 0.4923650568181818
# Epoch: 21 Loss: 0.6865759925408796 Accuracy: 0.5352450284090908
# Epoch: 31 Loss: 0.6268852027979764 Accuracy: 0.6669256036931819
# Epoch: 41 Loss: 0.5188583677465265 Accuracy: 0.8268821022727273
# Training on fold: 10
# Epoch: 1 Loss: 0.6932305043393915 Accuracy: 0.5114968039772727
# Epoch: 11 Loss: 0.6920986446467313 Accuracy: 0.5152698863636364
# Epoch: 21 Loss: 0.6770820834419944 Accuracy: 0.5837180397727273
# Epoch: 31 Loss: 0.5692325938831676 Accuracy: 0.7715953480113636
# Epoch: 41 Loss: 0.48723081025210296 Accuracy: 0.8532936789772727
# ---------------FINISHED----------------
# Accuracies: [0.85906428 0.82663796 0.88580877 0.83968839 0.89577415 0.89324396
#  0.86672141 0.90547319 0.89073597 0.88765092]
# Average accuracy: 0.8750799005681819
# Starting k-fold cross validation
# ---------------------------------------
# Training on fold: 1
# Epoch: 1 Loss: 0.6934882998466492 Accuracy: 0.5039284446022727
# Epoch: 11 Loss: 0.690673752264543 Accuracy: 0.5161576704545454
# Epoch: 21 Loss: 0.6583859432827343 Accuracy: 0.6284401633522727
# Epoch: 31 Loss: 0.5110014460303567 Accuracy: 0.8411532315340908
# Epoch: 41 Loss: 0.43653750148686493 Accuracy: 0.9048739346590908
# Training on fold: 2
# Epoch: 1 Loss: 0.6938854347575795 Accuracy: 0.49498401988636365
# Epoch: 11 Loss: 0.6917153651064093 Accuracy: 0.5005770596590909
# Epoch: 21 Loss: 0.6890525817871094 Accuracy: 0.5108531605113636
# Epoch: 31 Loss: 0.6430784030394121 Accuracy: 0.6376509232954546
# Epoch: 41 Loss: 0.4841224226084622 Accuracy: 0.8585094105113636
# Training on fold: 3
# Epoch: 1 Loss: 0.693823061206124 Accuracy: 0.5106534090909092
# Epoch: 11 Loss: 0.6916031295602972 Accuracy: 0.5008433948863636
# Epoch: 21 Loss: 0.687150012363087 Accuracy: 0.5298073508522727
# Epoch: 31 Loss: 0.5890880172902887 Accuracy: 0.7879527698863636
# Epoch: 41 Loss: 0.44938054138963873 Accuracy: 0.9111772017045454
# Training on fold: 4
# Epoch: 1 Loss: 0.6933766928586093 Accuracy: 0.5140269886363636
# Epoch: 11 Loss: 0.6907776485789906 Accuracy: 0.49740323153409094
# Epoch: 21 Loss: 0.6753000237724998 Accuracy: 0.5806329900568181
# Epoch: 31 Loss: 0.5354297865520824 Accuracy: 0.8090598366477273
# Epoch: 41 Loss: 0.44067362221804535 Accuracy: 0.9073375355113636
# Training on fold: 5
# Epoch: 1 Loss: 0.6936828981746327 Accuracy: 0.5008655894886364
# Epoch: 11 Loss: 0.6908290928060358 Accuracy: 0.4852849786931818
# Epoch: 21 Loss: 0.6653285730968822 Accuracy: 0.5995649857954546
# Epoch: 31 Loss: 0.5369202602993358 Accuracy: 0.7951438210227273
# Epoch: 41 Loss: 0.4733125567436218 Accuracy: 0.8707830255681819
# Training on fold: 6
# Epoch: 1 Loss: 0.693347616629167 Accuracy: 0.5116521661931819
# Epoch: 11 Loss: 0.6912088285792958 Accuracy: 0.5099653764204546
# Epoch: 21 Loss: 0.6681908910924738 Accuracy: 0.6238014914772727
# Epoch: 31 Loss: 0.5381291671232744 Accuracy: 0.7908824573863636
# Epoch: 41 Loss: 0.4439286481250416 Accuracy: 0.8933327414772727
# Training on fold: 7
# Epoch: 1 Loss: 0.6934545798735186 Accuracy: 0.4966042258522727
# Epoch: 11 Loss: 0.6912055286494169 Accuracy: 0.49995561079545453
# Epoch: 21 Loss: 0.670241957361048 Accuracy: 0.6163662997159092
# Epoch: 31 Loss: 0.5328863208944147 Accuracy: 0.8402876420454546
# Epoch: 41 Loss: 0.46246535127813165 Accuracy: 0.8887828480113636
# Training on fold: 8
# Epoch: 1 Loss: 0.6934843442656777 Accuracy: 0.5029740767045454
# Epoch: 11 Loss: 0.691057644107125 Accuracy: 0.5072354403409092
# Epoch: 21 Loss: 0.6660836338996887 Accuracy: 0.5920854048295454
# Epoch: 31 Loss: 0.5293607169931586 Accuracy: 0.83203125
# Epoch: 41 Loss: 0.42808679017153656 Accuracy: 0.9107555042613636
# Training on fold: 9
# Epoch: 1 Loss: 0.6935835697434165 Accuracy: 0.5154474431818181
# Epoch: 11 Loss: 0.6917926073074341 Accuracy: 0.5176890980113636
# Epoch: 21 Loss: 0.6873286691578951 Accuracy: 0.56298828125
# Epoch: 31 Loss: 0.6069440895860846 Accuracy: 0.7256747159090908
# Epoch: 41 Loss: 0.47705941037698224 Accuracy: 0.8725142045454546
# Training on fold: 10
# Epoch: 1 Loss: 0.6936926787549799 Accuracy: 0.49185458096590906
# Epoch: 11 Loss: 0.6913013674996116 Accuracy: 0.507080078125
# Epoch: 21 Loss: 0.6894604672085155 Accuracy: 0.5186434659090908
# Epoch: 31 Loss: 0.6615277582948859 Accuracy: 0.6506125710227273
# Epoch: 41 Loss: 0.5040137605233626 Accuracy: 0.8363148082386364
# ---------------FINISHED----------------
# Accuracies: [0.92502663 0.91896751 0.94347035 0.92693537 0.8762207  0.91723633
#  0.9087358  0.94062944 0.93013139 0.91810192]
# Average accuracy: 0.9205455433238638
# Models which passed the baseline: ['softmax model, 128 neurons, Learning Rate 0.001, Batch Size 2048, Regularization 0.001', 'sigmoid model, 128 neurons, Learning Rate 0.001, Batch Size 2048, Regularization 0.001']
